# %%
from data_read import Read
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from node2vec import Node2Vec

# %%
read = Read()

# %%
pr_pr = read.mat_protein_protein()

# %%
pr_pr
# Out:
#          Q9UI32  P00488  P35228  P06737  P11766  P50213  P30542  P00519  \
# Protein
# Q9UI32        0       0       0       0       0       0       0       0
# P00488        0       1       0       0       0       0       0       0
# P35228        0       0       1       0       0       0       0       0
# P06737        0       0       0       1       0       0       0       0
# P11766        0       0       0       0       1       0       0       0
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# P07510        0       0       0       0       0       0       0       0
# Q04844        0       0       0       0       0       0       0       0
# P31327        0       0       0       0       0       0       0       0
# P0C0L4        0       0       0       0       0       0       0       0
# P0C0L5        0       0       0       0       0       0       0       0
#
#          P12319  P00451  ...  O15111  Q99835  P02708  P11230  Q07001  P07510  \
# Protein                  ...
# Q9UI32        0       0  ...       0       0       0       0       0       0
# P00488        0       0  ...       0       0       0       0       0       0
# P35228        0       0  ...       0       0       0       0       0       0
# P06737        0       0  ...       0       0       0       0       0       0
# P11766        0       0  ...       0       0       0       0       0       0
# ...         ...     ...  ...     ...     ...     ...     ...     ...     ...
# P07510        0       0  ...       0       0       1       0       0       0
# Q04844        0       0  ...       0       0       1       0       0       0
# P31327        0       0  ...       0       0       0       0       0       0
# P0C0L4        0       0  ...       0       0       0       0       0       0
# P0C0L5        0       0  ...       0       0       0       0       0       0
#
#          Q04844  P31327  P0C0L4  P0C0L5
# Protein
# Q9UI32        0       0       0       0
# P00488        0       0       0       0
# P35228        0       0       0       0
# P06737        0       0       0       0
# P11766        0       0       0       0
# ...         ...     ...     ...     ...
# P07510        0       0       0       0
# Q04844        0       0       0       0
# P31327        0       0       0       0
# P0C0L4        0       0       0       0
# P0C0L5        0       0       0       0
#
# [1512 rows x 1512 columns]

# %%
def pandas_mat_2_stack(dataframe):
    stack = dataframe.stack()
    stack1 = stack[stack >= 1].rename_axis(('source', 'target')).reset_index(name='weight')
    stack2 = stack[stack == 0].rename_axis(('source', 'target')).reset_index(name='weight')
    all_stack = pd.concat([stack1,stack2])
    return all_stack

# %%
def stack_2_graph(stack):
    graph = nx.from_pandas_edgelist(stack,edge_attr=True)
    return graph

# %%
stack = pandas_mat_2_stack(pr_pr)

# %%
stw = stack_2_graph(stack)

# %%
edgelist = nx.to_edgelist(stw)

# %%
node2vec = Node2Vec(stw,dimensions = 16,walk_length=10,num_walks = 10 )
# Out:
# Computing transition probabilities:   0%|          | 0/1493 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13360/2969168421.py in <module>
# ----> 1 node2vec = Node2Vec(stw,dimensions = 16,walk_length=10,num_walks = 10 )
#
# ~\anaconda3\anaconda\lib\site-packages\node2vec\node2vec.py in __init__(self, graph, dimensions, walk_length, num_walks, p, q, weight_key, workers, sampling_strategy, quiet, temp_folder, seed)
#      71             np.random.seed(seed)
#      72
# ---> 73         self._precompute_probabilities()
#      74         self.walks = self._generate_walks()
#      75
#
# ~\anaconda3\anaconda\lib\site-packages\node2vec\node2vec.py in _precompute_probabilities(self)
#     120                     if destination == source:  # Backwards probability
#     121                         ss_weight = weight * 1 / p
# --> 122                     elif destination in self.graph[source]:  # If the neighbor is connected to the source
#     123                         ss_weight = weight
#     124                     else:
#
# ~\anaconda3\anaconda\lib\site-packages\networkx\classes\graph.py in __getitem__(self, n)
#     474         AtlasView({1: {}})
#     475         """
# --> 476         return self.adj[n]
#     477
#     478     def add_node(self, node_for_adding, **attr):
#
# ~\anaconda3\anaconda\lib\site-packages\networkx\classes\graph.py in adj(self)
#     353         For directed graphs, `G.adj` holds outgoing (successor) info.
#     354         """
# --> 355         return AdjacencyView(self._adj)
#     356
#     357     @property
#
# ~\anaconda3\anaconda\lib\site-packages\networkx\classes\coreviews.py in __init__(self, d)
#      43
#      44     def __init__(self, d):
# ---> 45         self._atlas = d
#      46
#      47     def __len__(self):
#
# KeyboardInterrupt:
